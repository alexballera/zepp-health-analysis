# %%
# Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime, timedelta

# Configuración de visualización
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# Warnings
import warnings
warnings.filterwarnings('ignore')

print("✓ Librerías cargadas")

# %% [markdown]
# ## 1. Cargar datos
#
# Cargar archivos CSV exportados desde Zepp. Ajustar nombres según lo exportado.

# %%
# Definir rutas
DATA_RAW = Path('../data/raw')
DATA_PROCESSED = Path('../data/processed')

# Listar archivos disponibles
print("Archivos en data/raw:")
for file in sorted(DATA_RAW.glob('*')):
    if file.is_file() and not file.name.startswith('.'):
        print(f"  - {file.name}")

# %%
# Ejemplo de carga (ajustar según estructura real)
# df_sleep = pd.read_csv(DATA_RAW / 'sleep.csv')
# df_heart = pd.read_csv(DATA_RAW / 'heart_rate.csv')
# df_activity = pd.read_csv(DATA_RAW / 'activity.csv')

# Placeholder: cargar primer archivo encontrado para inspección
# files = list(DATA_RAW.glob('*.csv'))
# if files:
#     df_sample = pd.read_csv(files[0])
#     print(f"Archivo: {files[0].name}")
#     display(df_sample.head())
#     print(f"\nShape: {df_sample.shape}")
#     print(f"\nColumnas: {list(df_sample.columns)}")

# %% [markdown]
# ## 2. Inspección de estructura
#
# Verificar tipos de datos, valores nulos, rangos.

# %%
# df_sample.info()
# df_sample.describe()

# %% [markdown]
# ## 3. Análisis temporal
#
# Identificar rango de fechas, frecuencia de registros.

# %%
# # Convertir columna de fecha si existe
# # df_sample['date'] = pd.to_datetime(df_sample['date'])
# # print(f"Rango: {df_sample['date'].min()} a {df_sample['date'].max()}")
# # print(f"Días con datos: {df_sample['date'].nunique()}")

# %% [markdown]
# ## 4. Visualización inicial
#
# Gráficos exploratorios básicos.

# %%
# # Ejemplo: línea de tiempo de una métrica
# # plt.figure(figsize=(14, 6))
# # plt.plot(df_sample['date'], df_sample['valor'], marker='o')
# # plt.title('Métrica en el tiempo')
# # plt.xlabel('Fecha')
# # plt.ylabel('Valor')
# # plt.xticks(rotation=45)
# # plt.tight_layout()
# # plt.show()

# %% [markdown]
# ## 5. Próximos pasos
#
# - Definir métricas clave según variables disponibles
# - Crear script de limpieza en `src/`
# - Análisis de correlaciones (sueño vs. estrés, actividad vs. FC en reposo, etc.)
# - Dashboard de métricas semanales/mensuales
